# %%
# Q1)Write a Python program to print the Fibonacci sequence up to a given number.
num=10
a=0
b=1
for _ in range(num):
    if a>num:
        break
    print(a,end=" ")
    c=a+b
    a=b
    b=c
# Out:
# 0 1 1 2 3 5 8

# %%
# Q2)Write a Python program to find the factorial of a given number.
num=int(input("Enter a number: "))
factorial=1
if num<0:
    print("Factorial does not exists for negative numbers")
elif num==0:
    print("The factorial for 0 is 1")
else:
    for i in range(1,num+1):
        factorial=num*i
    print(f"Factorial for {num} is {factorial}")
# Out:
# Factorial for 5 is 25

# %%
# Q3)Write a Python program to check whether a given string is a palindrome or not.
string=input("Enter a string: ")
if string==string[::-1]:
    print("String is Palindrome")
else:
    print("String is not a palindrome")
# Out:
# String is not a palindrome

# %%
# Q4)Write a Python program to count the number of vowels in a given string
# taking input from the user
count=0
string=input("enter a given string")
vowels="aeiouAEIOU"
# looping through each character and checking if its vowel or not
for char in string:
    if char in vowels:
        count+=1 
print("Number of Vowels in the string: ",count)
# Out:
# Number of Vowels in the string:  2

# %%
# Q5)Write a Python program to print the multiplication table of a given number
num=int(input("Enter a number for which you want to do: "))
for i in range(1,11):
    print(f"{num} x {i} = {num * i}")
# Out:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60
