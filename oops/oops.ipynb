# %%
class Car():

    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    #properties
    # make = 10
    # model = "audi"
    # year = 1990

    #behaviors
    def startEngine():
        print("Engine is starting ")
    
    def drive(self):
        print("Driver is driving")

# %%
class Employee:
    #class variables
    company_name = 'Yash Technologies'

    #constructor to initialize the object
    def __init__(self,name,salary):
        #instance variables
        self.name = name
        self.salary = salary
    
    #instance method
    def show(self):
        id = 100 #local variable
        print('Employee:',self.name, self.salary,self.company_name)

#create first object
user1 = Employee('Ankit', 10000) 
user1.show()

user2 = Employee('Isha', 30000)
user2.show()
# Out:
# Employee: Ankit 10000 Yash Technologies
# Employee: Isha 30000 Yash Technologies

# %%
class Demo:
    def __init__(self):
        print("Default conctructor called")

ob1 = Demo()
ob2 = Demo()
# Out:
# Default conctructor called
# Default conctructor called

# %%
class Bank:
    # set_balance = 30000
    def __init__(self,user_name, pan, address, set_balance):
            self.user_name = user_name
            self.pan = pan
            self.address = address
            self.set_balance = set_balance

    def deposit(self, amount):
         print("*******Deposit method called******")
         print("Initial balance of account = ",self.set_balance)
         print("Amount to deposit in bank is = ", amount)
         self.set_balance += amount
         print("After depositing some amount = ", self.set_balance)

    def withdrawal(self, amount):
         print("*******withdrawal method called******")
         print("Initial balance of your account = ",self.set_balance)
         print("Amount to withdraw from bank is = ", amount)
         self.set_balance -= amount
         print(f"After withdrawing {amount},now amount left = ", self.set_balance)
    
    def ministatement(self):
          print("*******MINISTATEMENT******")
          print("Account holder name is : ", self.user_name)
          print("PAN ID of USER1 is : ", self.pan)
          print(f"Account balance of {self.user_name} is : ", self.set_balance)
          print("Address of user1 is : ",self.address)
         


print("Welcome to HDFC BANK! We are ready to serve you!")
user1 = Bank("Shreenath Sharma", "RON237890894536", "kvnagar",30000)
user1.deposit(30000)
user1.withdrawal(20000)
user1.ministatement()


# user_name = input("Enter user name : ")
# pan = input("Enter user PAN Number : ")
# address = input("Enter user address : ")
# set_balance = input("Balance of your account : ")

# print(f"You entered {user_name} {pan} {address} {set_balance}")
# user1 = Bank(user_name, pan, address, set_balance)
# Out:
# Welcome to HDFC BANK! We are ready to serve you!
# *******Deposit method called******
# Initial balance of account =  30000
# Amount to deposit in bank is =  30000
# After depositing some amount =  60000
# *******withdrawal method called******
# Initial balance of your account =  60000
# Amount to withdraw from bank is =  20000
# After withdrawing 20000,now amount left =  40000
# *******MINISTATEMENT******
# Account holder name is :  Shreenath Sharma
# PAN ID of USER1 is :  RON237890894536
# Account balance of Shreenath Sharma is :  40000
# Address of user1 is :  kvnagar

# %%
class Bank:
    # set_balance = 30000
    def __init__(self,user_name, pan, address, set_balance):
            self.user_name = user_name
            self.pan = pan
            self.address = address
            self.set_balance = set_balance

    def deposit(self, amount):
         print("*******Deposit method called******")
         print("Initial balance of account = ",self.set_balance)
         print("Amount to deposit in bank is = ", amount)
         self.set_balance += amount
         print("After depositing some amount = ", self.set_balance)

    def withdrawal(self, amount):
         print("*******withdrawal method called******")
         print("Initial balance of your account = ",self.set_balance)
         print("Amount to withdraw from bank is = ", amount)
         self.set_balance -= amount
         print(f"After withdrawing {amount},now amount left = ", self.set_balance)
    
    def ministatement(self):
          print("*******MINISTATEMENT******")
          print("Account holder name is : ", self.user_name)
          print("PAN ID of USER1 is : ", self.pan)
          print(f"Account balance of {self.user_name} is : ", self.set_balance)
          print("Address of user1 is : ",self.address)


user1 = Bank("Shree", 237890, "kvnagar", 30000) # Create user account first

while True:
    print(" 1 for amount deposit")
    print(" 2 for amount withdraw")
    print(" 3 to view Bank statement")
    print(" 4 for Logging Out from process")
    choice = int(input("Enter your choice : "))
    
    match choice:
         case 1:
            amount = int(input("Enter amount for deposit : "))
            user1.deposit(amount)
      
         case 2:
            withdraw_amount = int(input("Enter withdraw amount: "))
            user1.withdrawal(withdraw_amount)
         
         case 3:
          user1.ministatement()

         case 4:
          print("Thanks for being with HDFC. We are happy to serve you")
          break  # Now 'break' will exit the loop
         case _: 
          print("Invalid choice")
# Out:
#  1 for amount deposit
#  2 for amount withdraw
#  3 to view Bank statement
#  4 for Logging Out from process
# *******MINISTATEMENT******
# Account holder name is :  Shree
# PAN ID of USER1 is :  237890
# Account balance of Shree is :  30000
# Address of user1 is :  kvnagar
#  1 for amount deposit
#  2 for amount withdraw
#  3 to view Bank statement
#  4 for Logging Out from process
# *******Deposit method called******
# Initial balance of account =  30000
# Amount to deposit in bank is =  20000
# After depositing some amount =  50000
#  1 for amount deposit
#  2 for amount withdraw
#  3 to view Bank statement
#  4 for Logging Out from process
# Thanks for being with HDFC. We are happy to serve you
