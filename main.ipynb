# %%
print('Hello World')
# Out:
# Hello World

# %%
def calculate(*vars, **kwargs):
    # print(vars)
    # print(type(vars))

    total = 0
    for val in vars:
        total +=val
    return total

# %%
print(calculate(10))
print(calculate(10,20))
print(calculate(10,20,40))
print(calculate(10,30,40,50,40,30))
print(calculate(10,30,40,50,40,30, 3,4,5,65,6,6))

displ(name = "Ravi", add = "Indore", mark = 300)
# Out:
# 10
# 30
# 70
# 200
# 289
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       4 print(calculate(10,30,40,50,40,30))
#       5 print(calculate(10,30,40,50,40,30, 3,4,5,65,6,6))
# ----> 7 displ(name = "Ravi", add = "Indore", mark = 300)
#
# NameError: name 'displ' is not defined

# %%
def rec_demo():
    print("hello1")
    print("hello2")

rec_demo()
# Out:
# hello1
# hello2

# %%
x = 4
y = 4
print(y == x)
# Out:
# True

# %%
a = 10
b = a
b = b + 1
print(b)
print(a)
print(a is b) 
a ==b
# Out:
# 10
# 10
# True
# True

# %%
s = "hello"
s = s.upper()
f"Hi, {s}"   #f-strings
# Out:
# 'Hi, HELLO'

# %%
a = 1005
b = 1990
a is b
# Out:
# False

# %%
s1 = "hello"
s2 = "hello"
print(s1 is s2)
s1 == s2
# Out:
# True
# True

# %%
my_list = [1,2,3]
print(my_list[0])
print(my_list[100])
# Out:
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 my_list = [1,2,3]
#       2 print(my_list[0])
# ----> 3 print(my_list[-100])
#
# IndexError: list index out of range

# %%
animal_list1 = ["Dog", "Cat", "Rat"]
animal_list2 = ["Dog", "Cat", "Rat"]
animal_list3 = ["DOG", "CAT", "RAT"]
print(animal_list1 == animal_list2)
print(animal_list1 == animal_list3)
print(animal_list1 != animal_list3)
# Out:
# True
# False
# True
# True

# %%
s = "level"
print(s[::-1])
print(s == s[::-1])
# Out:
# level
# True

# %%
l1 = [1,2]
l2 = [4,5,'\n',True,False]
l1.extend(l2)
print(l1)
print(l2)
# Out:
# [1, 2, 4, 5, '\n', True, False]
# [4, 5, '\n', True, False]

# %%
l1 = [10,20,30,40]
print(l1.pop(2))
print(l1)
print(l1.pop(100))
# Out:
# 30
# [10, 20, 40]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 4
#       2 print(l1.pop(2))
#       3 print(l1)
# ----> 4 print(l1.pop(100))
#
# IndexError: pop index out of range

# %%
l1 = [1,2, list('isha')]
print(sum(l1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 l1 = [1,2, list('isha')]
# ----> 2 print(sum(l1))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
l1 = [1,2,False]
print(all(l1))
# Out:
# False

# %%
values = (1,2,3)
print(values)
print(values[0])
# Out:
# (1, 2, 3)
# 1

# %%
value = 1,2,3,4,5
a,b,c,*rest = value
print(a)
print(b)
print(rest)
# Out:
# 1
# 2
# 4 5

# %%
a = 10
b = 20
c =30
l = (a,b,c)
print(l) 
print(len(l))
# Out:
# (10, 20, 30)
# 3

# %%
t = (30,20,90)
list = sorted(t)
print(list)
# Out:
# [20, 30, 90]

# %%
t = (30,20,90)
print(sorted(t))
# Out:
# [20, 30, 90]
